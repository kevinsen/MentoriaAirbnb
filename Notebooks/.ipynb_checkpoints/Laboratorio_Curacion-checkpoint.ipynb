# %% [markdown]
# # Laboratorio: Curando un Dataset

# %% [markdown]
# ## ¿A dónde realizan su primera reserva los nuevos usuarios de Airbnb?
#
# Durante este práctico vamos a trabajar sobre el dataset [Airbnb New User Bookings](https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data) de Kaggle.
#
# Airbnb nos ofrece una lista de usuarios (todos de EEUU) junto con sus datos demográficos, registros de sesiones web y algunas estadísticas extras. Hay 12 posibles resultados del país de destino:  __US__, __FR__, __CA__, __GB__, __ES__, __IT__, __PT__, __NL__, __DE__, __AU__, __NDF__ (no se ha encontrado ningún destino), y __other__.
#
# Las variables con las que trabaja el dataset son:
#  * __id__: identificación de usuario.
#  * __date_account_created__: fecha de la creación de la cuenta.
#  * __timestamp_first_active__: timestamp de primera actividad.
#  * __date_first_booking__: fecha de primer viaje.
#  * __gender__: género.
#  * __age__: edad.
#  * __signup_method__: método de registración.
#  * __signup_flow__: la página desde la cual un usuario vino a registrarse.
#  * __language__: preferencia de idioma internacional.
#  * __affiliate_channel__: tipo de marketing pagado.
#  * __affiliate_provider__: de donde es el marketing.
#  * __first_affiliate_tracked__: seguimiento previo a la registración.
#  * __signup_app__: aplicación de registración.
#  * __first_device_type__: tipo de dispositivo.
#  * __first_browser__: búscador.
#  * __country_destination__: país escogido para realizar un viaje.
#
# ## Objetivo y alcance:
#
# En este laboratorio realizaremos un trabajo de curación sobre el dataset de Airbnb, una tarea fundamental antes de querer comenzar a aplicar conceptos de aprendizaje automático. Para poder definir un método o "receta" de curación, hemos definido una lista de pasos a seguir para llevar a cabo la curación de cualquier dataset:
#
#   1. Verificar que no hay problemas en la importación.
#   2. Asegurar de tener IDs/claves únicas.
#   3. Despersonalizar datos y guardarlos en un nuevo archivo.
#   4. Nunca modificar los datos crudos u originales.
#   5. Etiquetas de variables/columnas: no usar caracteres especiales.
#   6. Tratar valores faltantes.
#   7. Codificar variables.
#   8. No cambiar los nombres de las variables de la fuente de origen.
#   9. Verificar la consistencia de las variables.
#   10. Identificar y documentar valores atípicos/outliers.
#   11. Evaluar cómo comprimir los datos.
#   12. Guardar el set de datos con un nombre informativo.
#
# Siguiendo los pasos anteriores, uno puede curar cualquier conjunto de datos, con la seguridad de que estamos haciendo las cosas de una manera coherente.
#
#
# ## Estructura del informe:
#
#   * Jupyter Notebook con el análisis realizado.
#
# ---

# %% [markdown]
# ## 1. Verificar que no hay problemas en la importación

# %% [markdown]
# Comenzamos importando la librería __pandas__.

# %%
import pandas as pd

# %% [markdown]
# También importamos la librería __warnings__ para que no se muestren los avisos de warning, sólo para una comodidad visual.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Luego, leemos el dataset __Building_Permits.cvs__ y luego lo mostramos

# %%
data = pd.read_csv("../Datos/data.csv") #Path a los datos
data
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn           2010-06-
# 2              2010-08-02     FEMALE  56.0         basic            3
# 3              2012-09-08     FEMALE  42.0      facebook            0
# 4              2010-02-18  -unknown-  41.0         basic            0
# 5              2010-01-02  -unknown-   NaN         basic            0
# 6              2010-01-05     FEMALE  46.0         basic            0
# 7              2010-01-13     FEMALE  47.0         basic            0
# 8              2010-07-29     FEMALE  50.0         basic            0
# 9              2010-01-04  -unknown-  46.0         basic            0
# 10             2010-01-06     FEMALE  36.0         basic            0
# 11                    NaN     FEMALE  47.0         basic            0
# 12             2010-01-18  -unknown-   NaN         basic            0
# 13                    NaN     FEMALE  37.0         basic            0
# 14                    NaN     FEMALE  36.0         basic            0
# 15             2010-01-08     FEMALE  33.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17             2010-01-09  -unknown-  31.0         basic            0
# 18                    NaN  -unknown-   NaN         basic            0
# 19             2010-01-10     FEMALE  29.0         basic            0
# 20             2010-01-18  -unknown-   NaN         basic            0
# 21             2010-01-11       MALE  30.0         basic            0
# 22             2010-01-11  -unknown-  40.0         basic            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN     FEMALE  40.0         basic            0
# 25             2010-01-15     FEMALE  26.0         basic            0
# 26                    NaN  -unknown-   NaN         basic            0
# 27             2010-01-22     FEMALE  32.0         basic            0
# 28             2010-01-13  -unknown-  35.0         basic            0
# 29             2010-01-19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 213421                NaN  -unknown-   NaN         basic            0
# 213422                NaN  -unknown-   NaN         basic            0
# 213423                NaN     FEMALE  20.0      facebook           25
# 213424                NaN     FEMALE  32.0      facebook            0
# 213425                NaN     FEMALE  30.0      facebook            0
# 213426                NaN  -unknown-   NaN         basic            0
# 213427                NaN  -unknown-   NaN         basic            0
# 213428                NaN  -unknown-   NaN         basic           23
# 213429                NaN  -unknown-   NaN         basic           25
# 213430                NaN  -unknown-  19.0         basic            0
# 213431                NaN  -unknown-   NaN         basic            0
# 213432                NaN       MALE  31.0      facebook            0
# 213433                NaN  -unknown-   NaN         basic            0
# 213434                NaN  -unknown-   NaN         basic            0
# 213435                NaN  -unknown-   NaN         basic            0
# 213436                NaN  -unknown-   NaN         basic           25
# 213437                NaN  -unknown-   NaN         basic           23
# 213438                NaN  -unknown-   NaN         basic           25
# 213439         2015-03-16       MALE  43.0         basic            0
# 213440                NaN     FEMALE  24.0         basic           25
# 213441         2014-08-13     FEMALE  34.0         basic            0
# 213442                NaN  -unknown-   NaN         basic            0
# 213443         2014-07-13     FEMALE  36.0         basic            0
# 213444                NaN  -unknown-   NaN         basic            0
# 213445         2014-07-02     FEMALE  23.0         basic            0
# 213446                NaN       MALE  32.0         basic            0
# 213447                NaN  -unknown-   NaN         basic            0
# 213448                NaN  -unknown-  32.0         basic            0
# 213449                NaN  -unknown-   NaN         basic           25
# 213450                NaN  -unknown-   NaN         basic           25
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 0            en            direct             direct               untracked
# 1            en               seo             google               untracked
# 2            en            direct             direct               untracked
# 3            en            direct             direct               untracked
# 4            en            direct             direct               untracked
# 5            en             other              other                     omg
# 6            en             other         craigslist               untracked
# 7            en            direct             direct                     omg
# 8            en             other         craigslist               untracked
# 9            en             other         craigslist                     omg
# 10           en             other         craigslist               untracked
# 11           en             other         craigslist               untracked
# 12           en            direct             direct                     NaN
# 13           en             other         craigslist                  linked
# 14           en             other         craigslist               untracked
# 15           en            direct             direct               untracked
# 16           en             other         craigslist                     NaN
# 17           en             other         craigslist                     NaN
# 18           en               seo           facebook                     NaN
# 19           en            direct             direct               untracked
# 20           en            direct             direct                     NaN
# 21           en            direct             direct                  linked
# 22           en               seo             google               untracked
# 23           en             other         craigslist               untracked
# 24           en               seo             google               untracked
# 25           en             other         craigslist               untracked
# 26           en             other              other               untracked
# 27           en             other         craigslist               untracked
# 28           en            direct             direct                     NaN
# 29           en            direct             direct               untracked
# ...         ...               ...                ...                     ...
# 213421       en            direct             direct                  linked
# 213422       en            direct             direct               untracked
# 213423       en            direct             direct               untracked
# 213424       en            direct             direct                  linked
# 213425       en            direct             direct                  linked
# 213426       en            direct             direct               untracked
# 213427       en            direct             direct                  linked
# 213428       en            direct             direct               untracked
# 213429       en            direct             direct               untracked
# 213430       en            direct             direct                  linked
# 213431       en            direct             direct               untracked
# 213432       en            direct             direct           tracked-other
# 213433       en         sem-brand             google               untracked
# 213434       en               seo           facebook                 product
# 213435       en               seo             google               untracked
# 213436       en            direct             direct               untracked
# 213437       en            direct             direct               untracked
# 213438       en            direct             direct               untracked
# 213439       en            direct             direct               untracked
# 213440       en            direct             direct               untracked
# 213441       en            direct             direct                  linked
# 213442       en         sem-brand             google                     omg
# 213443       en         sem-brand             google                  linked
# 213444       en            direct             direct                  linked
# 213445       en         sem-brand             google                     omg
# 213446       en         sem-brand             google                     omg
# 213447       en            direct             direct                  linked
# 213448       en            direct             direct               untracked
# 213449       en             other              other           tracked-other
# 213450       en            direct             direct               untracked
#
#        signup_app first_device_type  first_browser country_destination
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 213421        Web       Mac Desktop        Firefox                 NDF
# 213422        Web   Windows Desktop             IE                 NDF
# 213423        iOS            iPhone      -unknown-                 NDF
# 213424        Web   Windows Desktop         Chrome                 NDF
# 213425        Web   Windows Desktop         Chrome                 NDF
# 213426      Moweb     Android Phone  Chrome Mobile                 NDF
# 213427        Web   Desktop (Other)         Chrome                 NDF
# 213428    Android     Android Phone      -unknown-                 NDF
# 213429        iOS            iPhone      -unknown-                 NDF
# 213430        Web       Mac Desktop         Chrome                 NDF
# 213431        Web   Windows Desktop        Firefox                 NDF
# 213432        Web       Mac Desktop         Safari                 NDF
# 213433        Web              iPad  Mobile Safari                 NDF
# 213434        Web       Mac Desktop         Chrome                 NDF
# 213435        Web   Windows Desktop         Chrome                 NDF
# 213436        iOS            iPhone      -unknown-                 NDF
# 213437    Android    Android Tablet      -unknown-                 NDF
# 213438        iOS            iPhone      -unknown-                 NDF
# 213439        Web   Windows Desktop        Firefox                  US
# 213440        iOS            iPhone  Mobile Safari                 NDF
# 213441        Web       Mac Desktop         Chrome                  ES
# 213442        Web       Mac Desktop         Chrome                 NDF
# 213443        Web       Mac Desktop         Safari                  US
# 213444        Web   Windows Desktop         Chrome                 NDF
# 213445        Web   Windows Desktop             IE                  US
# 213446        Web       Mac Desktop         Safari                 NDF
# 213447        Web   Windows Desktop         Chrome                 NDF
# 213448        Web       Mac Desktop        Firefox                 NDF
# 213449        iOS            iPhone  Mobile Safari                 NDF
# 213450        iOS            iPhone      -unknown-                 NDF
#
# [213451 rows x 16 columns]

# %% [markdown]
# Como vemos, no obtuvimos ningún error a la hora de la lectura del conjunto de datos, lo que es un buen comienzo.

# %% [markdown]
# Además, podemos observar que el dataset está formado por 213451 filas y 16 columnas
# ***

# %% [markdown]
# Seteamos la semillla para reproducibilidad.

# %%
import numpy as np
np.random.seed(0)

# %% [markdown]
# Mostramos __aleatoriamente__ 5 muestras del dataset.

# %%
data.sample(5)
# Out:
#                 id date_account_created  timestamp_first_active  \
# 76214   vwcvba5tbi           2013-05-10          20130510181208
# 197283  lh49nmvbhr           2014-05-30          20140530230300
# 65429   peowrqmisu           2013-03-15          20130315150346
# 151272  568wanlyy1           2014-02-10          20140210064831
# 137127  ihi4gy0dyl           2014-01-01          20140101193508
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 76214          2013-05-17       MALE  43.0      facebook            0
# 197283         2014-12-15     FEMALE  35.0         basic            0
# 65429                 NaN  -unknown-   NaN         basic            0
# 151272                NaN  -unknown-   NaN         basic            0
# 137127         2014-01-06     FEMALE  29.0         basic            0
#
#        language affiliate_channel affiliate_provider first_affiliate_tracked  \
# 76214        en            direct             direct                  linked
# 197283       en         sem-brand             google                     omg
# 65429        en            direct             direct                  linked
# 151272       en            direct             direct               untracked
# 137127       en            direct             direct               untracked
#
#        signup_app first_device_type first_browser country_destination
# 76214         Web       Mac Desktop        Chrome                  US
# 197283        Web   Windows Desktop        Chrome                  CA
# 65429         Web       Mac Desktop        Safari                 NDF
# 151272        Web       Mac Desktop        Safari                 NDF
# 137127        Web   Windows Desktop        Chrome               other

# %%
data.dtypes
# Out:
# id                          object
# date_account_created        object
# timestamp_first_active       int64
# date_first_booking          object
# gender                      object
# age                        float64
# signup_method               object
# signup_flow                  int64
# language                    object
# affiliate_channel           object
# affiliate_provider          object
# first_affiliate_tracked     object
# signup_app                  object
# first_device_type           object
# first_browser               object
# country_destination         object
# dtype: object

# %% [markdown]
# Los campos __objects__ generalmente son __strings__. En nuestro caso, no se reconocieron como fechas a __date_account_created__, __timestamp_first_active__, __date_first_booking__, lo cual ya lo observamos en el laboratorio de visualización.

# %% [markdown]
# Veamos un resumen de los datos, incluyendo todos los tipos de datos __numéricos__ y __categóricos__.

# %%
data.describe(include='all')
# Out:
#                 id date_account_created  timestamp_first_active  \
# count       213451               213451            2.134510e+05
# unique      213451                 1634                     NaN
# top     ywi0s7shb2           2014-05-13                     NaN
# freq             1                  674                     NaN
# mean           NaN                  NaN            2.013085e+13
# std            NaN                  NaN            9.253717e+09
# min            NaN                  NaN            2.009032e+13
# 25%            NaN                  NaN            2.012123e+13
# 50%            NaN                  NaN            2.013091e+13
# 75%            NaN                  NaN            2.014031e+13
# max            NaN                  NaN            2.014063e+13
#
#        date_first_booking     gender            age signup_method  \
# count               88908     213451  125461.000000        213451
# unique               1976          4            NaN             3
# top            2014-05-22  -unknown-            NaN         basic
# freq                  248      95688            NaN        152897
# mean                  NaN        NaN      49.668335           NaN
# std                   NaN        NaN     155.666612           NaN
# min                   NaN        NaN       1.000000           NaN
# 25%                   NaN        NaN      28.000000           NaN
# 50%                   NaN        NaN      34.000000           NaN
# 75%                   NaN        NaN      43.000000           NaN
# max                   NaN        NaN    2014.000000           NaN
#
#           signup_flow language affiliate_channel affiliate_provider  \
# count   213451.000000   213451            213451             213451
# unique            NaN       25                 8                 18
# top               NaN       en            direct             direct
# freq              NaN   206314            137727             137426
# mean         3.267387      NaN               NaN                NaN
# std          7.637707      NaN               NaN                NaN
# min          0.000000      NaN               NaN                NaN
# 25%          0.000000      NaN               NaN                NaN
# 50%          0.000000      NaN               NaN                NaN
# 75%          0.000000      NaN               NaN                NaN
# max         25.000000      NaN               NaN                NaN
#
#        first_affiliate_tracked signup_app first_device_type first_browser  \
# count                   207386     213451            213451        213451
# unique                       7          4                 9            52
# top                  untracked        Web       Mac Desktop        Chrome
# freq                    109232     182717             89600         63845
# mean                       NaN        NaN               NaN           NaN
# std                        NaN        NaN               NaN           NaN
# min                        NaN        NaN               NaN           NaN
# 25%                        NaN        NaN               NaN           NaN
# 50%                        NaN        NaN               NaN           NaN
# 75%                        NaN        NaN               NaN           NaN
# max                        NaN        NaN               NaN           NaN
#
#        country_destination
# count               213451
# unique                  12
# top                    NDF
# freq                124543
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %% [markdown]
# * __TO DO__: Indicamos explícitamente aquellas columnas que son fechas y no fueron detectadas como tales. Luego chequeamos que el cambio aplicado se haya reflejado en el dataset.

# %%
#hago una copia de los datos para manipularlos y no tocar el original
cdata = data
#set corrects datetypes
dcol = ['date_account_created','timestamp_first_active','date_first_booking']

for i in dcol:
    if 'timestamp' not in i:
        cdata[i] = pd.to_datetime(cdata[i],format= '%Y-%m-%d')
    else:
        cdata[i] = pd.to_datetime(cdata[i],format='%Y%m%d%H%M%S')

# %%
#vemos tambien que el genero tiene valores -unknow- 
#los cuales mantendremos ya que son la mayor parte de los usuarios
cdata['gender'].value_counts()
# Out:
# -unknown-    95688
# FEMALE       63041
# MALE         54440
# OTHER          282
# Name: gender, dtype: int64

# %% [markdown]
# * __TO DO__: Ahora deberíamos poder calcular los rangos de las distintas fechas: __date_account_created__, __timestamp_first_active__, __date_first_booking__.

# %%
cdata.dtypes
cdata.describe(include='all')
#cdata.head(10)
# Out:
#                 id date_account_created timestamp_first_active  \
# count       213451               213451                 213451
# unique      213451                 1634                 213451
# top     ywi0s7shb2  2014-05-13 00:00:00    2013-07-01 05:26:34
# freq             1                  674                      1
# first          NaN  2010-01-01 00:00:00    2009-03-19 04:32:55
# last           NaN  2014-06-30 00:00:00    2014-06-30 23:58:24
# mean           NaN                  NaN                    NaN
# std            NaN                  NaN                    NaN
# min            NaN                  NaN                    NaN
# 25%            NaN                  NaN                    NaN
# 50%            NaN                  NaN                    NaN
# 75%            NaN                  NaN                    NaN
# max            NaN                  NaN                    NaN
#
#          date_first_booking     gender            age signup_method  \
# count                 88908     213451  125461.000000        213451
# unique                 1976          4            NaN             3
# top     2014-05-22 00:00:00  -unknown-            NaN         basic
# freq                    248      95688            NaN        152897
# first   2010-01-02 00:00:00        NaN            NaN           NaN
# last    2015-06-29 00:00:00        NaN            NaN           NaN
# mean                    NaN        NaN      49.668335           NaN
# std                     NaN        NaN     155.666612           NaN
# min                     NaN        NaN       1.000000           NaN
# 25%                     NaN        NaN      28.000000           NaN
# 50%                     NaN        NaN      34.000000           NaN
# 75%                     NaN        NaN      43.000000           NaN
# max                     NaN        NaN    2014.000000           NaN
#
#           signup_flow language affiliate_channel affiliate_provider  \
# count   213451.000000   213451            213451             213451
# unique            NaN       25                 8                 18
# top               NaN       en            direct             direct
# freq              NaN   206314            137727             137426
# first             NaN      NaN               NaN                NaN
# last              NaN      NaN               NaN                NaN
# mean         3.267387      NaN               NaN                NaN
# std          7.637707      NaN               NaN                NaN
# min          0.000000      NaN               NaN                NaN
# 25%          0.000000      NaN               NaN                NaN
# 50%          0.000000      NaN               NaN                NaN
# 75%          0.000000      NaN               NaN                NaN
# max         25.000000      NaN               NaN                NaN
#
#        first_affiliate_tracked signup_app first_device_type first_browser  \
# count                   207386     213451            213451        213451
# unique                       7          4                 9            52
# top                  untracked        Web       Mac Desktop        Chrome
# freq                    109232     182717             89600         63845
# first                      NaN        NaN               NaN           NaN
# last                       NaN        NaN               NaN           NaN
# mean                       NaN        NaN               NaN           NaN
# std                        NaN        NaN               NaN           NaN
# min                        NaN        NaN               NaN           NaN
# 25%                        NaN        NaN               NaN           NaN
# 50%                        NaN        NaN               NaN           NaN
# 75%                        NaN        NaN               NaN           NaN
# max                        NaN        NaN               NaN           NaN
#
#        country_destination
# count               213451
# unique                  12
# top                    NDF
# freq                124543
# first                  NaN
# last                   NaN
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %% [markdown]
# Los rangos de las distintas fechas son:
# * date_account_created= 2010-01-01 00:00:00 to 2014-06-30 00:00:00
# * timestamp_first_active= 2009-03-19 04:32:55	to 2014-06-30 23:58:24
# * date_first_booking= 2010-01-02 00:00:00	to 2015-06-29 00:00:00
#
# veamos estos rangos en dias...

# %%
cdata['date_account_created'].max() - cdata['date_account_created'].min()
# Out:
# Timedelta('1641 days 00:00:00')

# %%
cdata['timestamp_first_active'].max() - cdata['timestamp_first_active'].min()
# Out:
# Timedelta('1929 days 19:25:29')

# %%
cdata['date_first_booking'].max() - cdata['date_first_booking'].min()
# Out:
# Timedelta('2004 days 00:00:00')

# %% [markdown]
# # 2. Asegurar de tener IDs/claves únicas

# %%
cdata.shape
# Out:
# (213451, 16)

# %% [markdown]
# * __TO DO__: Definimos como índice del dataset a la columna __id__.

# %%
cdata = cdata.set_index('id')
cdata.head()
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %%
cdata.shape
# Out:
# (213451, 15)

# %% [markdown]
# * __TO DO__: Chequear que no existan "ids" duplicados.

# %%
cdata[cdata.duplicated()]
# Out:
# Empty DataFrame
# Columns: [date_account_created, timestamp_first_active, date_first_booking, gender, age, signup_method, signup_flow, language, affiliate_channel, affiliate_provider, first_affiliate_tracked, signup_app, first_device_type, first_browser, country_destination]
# Index: []

# %%
#verificamos si en pandas no hay duplicados
pd.Series(cdata.index,dtype=str).describe()
# Out:
# count         213451
# unique        213451
# top       ywi0s7shb2
# freq               1
# Name: id, dtype: object

# %% [markdown]
# ## 1.3. Despersonalizar datos y guardarlos en un nuevo archivo

# %% [markdown]
# Cualquier dataset con información sensible de usuarios, como por ejemplo: Nombres, DNI, lugar de residencia de las personas, etc, deben de manejar con mucha precaución. Para más información [Reglamento General de Protección de Datos](https://es.wikipedia.org/wiki/Reglamento_General_de_Protecci%C3%B3n_de_Datos)

# %% [markdown]
# * __TO DO__: ¿Nuestro dataset tiene alguna información sensible que deba de ser despersonalizada? En caso de ser así, tenemos que despersonalizarlo.
#
# No, nuestro dataset no tiene info. sensible.

# %% [markdown]
# * __TO DO__: Si considerás que el dataset es seguro, a modo de práctica despersonaliza una columna cualquiera.

# %%
from hashlib import md5

# %%
data_with_hash = cdata.copy(deep=True)
data_with_hash.head()
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %%
def hashit(val):
    if isinstance(val, float): 
        return str(val)
    return md5(val.encode('utf-8')).hexdigest()

# %%
data_with_hash['first_device_type'].apply(hashit)
# Out:
# id
# gxn3p5htnn    16c8cc687c424e33794cbce8012f4e91
# 820tgsjxq7    16c8cc687c424e33794cbce8012f4e91
# 4ft3gnwmtx    e109863613aea55882ab275a02025009
# bjjt8pjhuk    16c8cc687c424e33794cbce8012f4e91
# 87mebub9p4    16c8cc687c424e33794cbce8012f4e91
# osr2jwljor    16c8cc687c424e33794cbce8012f4e91
# lsw9q7uk0j    16c8cc687c424e33794cbce8012f4e91
# 0d01nltbrs    16c8cc687c424e33794cbce8012f4e91
# a1vcnhxeij    16c8cc687c424e33794cbce8012f4e91
# 6uh8zyj2gn    16c8cc687c424e33794cbce8012f4e91
# yuuqmid2rp    16c8cc687c424e33794cbce8012f4e91
# om1ss59ys8    867e57bd062c7169995dc03cc0541c19
# k6np330cm1    09b88a2c073ae72c98764bda25f2de42
# ## 4. Nunca modificar los datos crudos u originales

# %%
data.to_csv("../Datos/data_original.csv")

# %% [markdown]
# ## 5. Etiquetas de variables/columnas: no usar caracteres especiales

# %%
cdata.describe(include='all')
# Out:
#        date_account_created timestamp_first_active   date_first_booking  \
# count                213451                 213451                88908
# unique                 1634                 213451                 1976
# top     2014-05-13 00:00:00    2013-07-01 05:26:34  2014-05-22 00:00:00
# freq                    674                      1                  248
# first   2010-01-01 00:00:00    2009-03-19 04:32:55  2010-01-02 00:00:00
# last    2014-06-30 00:00:00    2014-06-30 23:58:24  2015-06-29 00:00:00
# mean                    NaN                    NaN                  NaN
# std                     NaN                    NaN                  NaN
# min                     NaN                    NaN                  NaN
# 25%                     NaN                    NaN                  NaN
# 50%                     NaN                    NaN                  NaN
# 75%                     NaN                    NaN                  NaN
# max                     NaN                    NaN                  NaN
#
#            gender            age signup_method    signup_flow language  \
# count      213451  125461.000000        213451  213451.000000   213451
# unique          4            NaN             3            NaN       25
# top     -unknown-            NaN         basic            NaN       en
# freq        95688            NaN        152897            NaN   206314
# first         NaN            NaN           NaN            NaN      NaN
# last          NaN            NaN           NaN            NaN      NaN
# mean          NaN      49.668335           NaN       3.267387      NaN
# std           NaN     155.666612           NaN       7.637707      NaN
# min           NaN       1.000000           NaN       0.000000      NaN
# 25%           NaN      28.000000           NaN       0.000000      NaN
# 50%           NaN      34.000000           NaN       0.000000      NaN
# 75%           NaN      43.000000           NaN       0.000000      NaN
# max           NaN    2014.000000           NaN      25.000000      NaN
#
#        affiliate_channel affiliate_provider first_affiliate_tracked  \
# count             213451             213451                  207386
# unique                 8                 18                       7
# top               direct             direct               untracked
# freq              137727             137426                  109232
# first                NaN                NaN                     NaN
# last                 NaN                NaN                     NaN
# mean                 NaN                NaN                     NaN
# std                  NaN                NaN                     NaN
# min                  NaN                NaN                     NaN
# 25%                  NaN                NaN                     NaN
# 50%                  NaN                NaN                     NaN
# 75%                  NaN                NaN                     NaN
# max                  NaN                NaN                     NaN
#
#        signup_app first_device_type first_browser country_destination
# count      213451            213451        213451              213451
# unique          4                 9            52                  12
# top           Web       Mac Desktop        Chrome                 NDF
# freq       182717             89600         63845              124543
# first         NaN               NaN           NaN                 NaN
# last          NaN               NaN           NaN                 NaN
# mean          NaN               NaN           NaN                 NaN
# std           NaN               NaN           NaN                 NaN
# min           NaN               NaN           NaN                 NaN
# 25%           NaN               NaN           NaN                 NaN
# 50%           NaN               NaN           NaN                 NaN
# 75%           NaN               NaN           NaN                 NaN
# max           NaN               NaN           NaN                 NaN

# %% [markdown]
# Se importan librerías útiles para el manejo de __encodings__.

# %%
import chardet
import string

# %% [markdown]
# ¿Cúales son los caracteres "normales"?

# %%
string.ascii_letters + string.digits
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789'

# %% [markdown]
# En particular, Python 3 utiliza __UTF-8__ por defecto.

# %% [markdown]
# Vamos a averiguar el enconding de nuestro dataset.

# %%
with open("../Datos/data.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))
print(result)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# * __TO DO__: Volviendo a la consigna original, chequeamos que no haya caracteres fuera de __a-Z__, __0-9__

# %%
cdata.columns[~cdata.columns.str.match(r'^(\w+)$')]
# Out:
# Index([], dtype='object')

# %% [markdown]
# * __TO DO__: Reemplazar espacios por _.

# %%
cdata.columns = cdata.columns.str.replace(' ','_')
cdata.head()
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender   age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-   NaN      facebook            0       en
# 820tgsjxq7       MALE  38.0      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.0         basic            3       en
# bjjt8pjhuk     FEMALE  42.0      facebook            0       en
# 87mebub9p4  -unknown-  41.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %% [markdown]
# ## 6. Tratar valores faltantes

# %% [markdown]
# Vamos a ver cuantos valores nulos tenemos.

# %%
missing_values_count = cdata.isnull().sum()
missing_values_count[missing_values_count > 0]
# Out:
# date_first_booking         124543
# age                         87990
# first_affiliate_tracked      6065
# dtype: int64

# %% [markdown]
# * __TO DO__: Calcular el porcentaje de datos faltantes por columna. Ejemplo:

# %%
len(cdata.dropna())/len(cdata)
# Out:
# 0.3193754070020754

# %% [markdown]
# * __TO DO__: ¿Existen algunas columnas donde las casillas vacías son demasiadas, tanto que se aproximan al número total de muestras del dataset? Si es así, debemos proceder a obviarlas, en lugar de reemplazar los valores faltantes con algún otro valor.

# %%
len(cdata.dropna(subset=['date_first_booking']))/len(cdata)
# Out:
# 0.4165265095970504

# %% [markdown]
# En este caso encontramos en date_first_booking cerca de un 58% de los datos en nulo, pero en este caso ese valor vacio representa usuarios que hicieron su primer reserva, por lo tanto no podemos eliminarlos y es mejor obviarlos.

# %% [markdown]
# * __TO DO__: Dentro de los valores que quedan, se puede observar que para algunas categorías existe una gran cantidad de valores faltantes y eliminar estas filas sería perder mucha información. Pero para las categorías donde las filas de valores faltantes no representan mucho respecto al tamaño del dataset, directamente las podemos descartar.

# %%
len(cdata.dropna(subset=['first_affiliate_tracked']))/len(cdata)
# Out:
# 0.971585984605366

# %%
len(cdata[cdata.date_first_booking.notna()].dropna(subset=['first_affiliate_tracked']))/ \
len(cdata[cdata.date_first_booking.notna()])
# Out:
# 0.98045170288388

# %% [markdown]
# Vemos que es seguro eliminar los valores nulos de first_affiliate_tracked

# %%
cdata = cdata.dropna(subset=['first_affiliate_tracked'])

# %% [markdown]
# Ahora observamos que sucede con age

# %%
len(cdata.dropna(subset=['age']))/len(cdata)
# Out:
# 0.5951655367286124

# %%
#controlemos cuantos que han reservado y no tienen age
len(cdata[cdata.date_first_booking.notna()].dropna(subset=['age']))/ \
len(cdata[cdata.date_first_booking.notna()])
# Out:
# 0.7820465756567626

# %% [markdown]
# * __TO DO__: Finalmente para las categorías que no deseamos borrar filas para no perder datos, debemos reemplazar los valores faltantes por algún valor, como por ejemplo: 0 en caso de columnas numéricas, None para strings (tipo object) y la fecha más común para el caso de las fechas. Una vez hecho esto hemos logrado sacar todos los valores faltantes.

# %% [markdown]
# En el caso de age tampoco se puede borrar ya que representan una parte importante del dataset. Por ende los llenaremos con valores medios.

# %%
cdata['age'].fillna(cdata['age'].mean(), inplace=True)
cdata.head(10)
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
# osr2jwljor           2010-01-01    2010-01-01 21:56:19         2010-01-02
# lsw9q7uk0j           2010-01-02    2010-01-02 01:25:58         2010-01-05
# 0d01nltbrs           2010-01-03    2010-01-03 19:19:05         2010-01-13
# a1vcnhxeij           2010-01-04    2010-01-04 00:42:11         2010-07-29
# 6uh8zyj2gn           2010-01-04    2010-01-04 02:37:58         2010-01-04
#
#                gender        age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-  49.307715      facebook            0       en
# 820tgsjxq7       MALE  38.000000      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.000000         basic            3       en
# bjjt8pjhuk     FEMALE  42.000000      facebook            0       en
# 87mebub9p4  -unknown-  41.000000         basic            0       en
# osr2jwljor  -unknown-  49.307715         basic            0       en
# lsw9q7uk0j     FEMALE  46.000000         basic            0       en
# 0d01nltbrs     FEMALE  47.000000         basic            0       en
# a1vcnhxeij     FEMALE  50.000000         basic            0       en
# 6uh8zyj2gn  -unknown-  46.000000         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
# osr2jwljor             other              other                     omg
# lsw9q7uk0j             other         craigslist               untracked
# 0d01nltbrs            direct             direct                     omg
# a1vcnhxeij             other         craigslist               untracked
# 6uh8zyj2gn             other         craigslist                     omg
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US
# osr2jwljor        Web       Mac Desktop        Chrome                  US
# lsw9q7uk0j        Web       Mac Desktop        Safari                  US
# 0d01nltbrs        Web       Mac Desktop        Safari                  US
# a1vcnhxeij        Web       Mac Desktop        Safari                  US
# 6uh8zyj2gn        Web       Mac Desktop       Firefox                  US

# %%
missing_values_count = cdata.isnull().sum()
missing_values_count[missing_values_count > 0]
# Out:
# date_first_booking    120216
# dtype: int64

# %% [markdown]
# ## 7. Codificar variables

# %% [markdown]
# Las variables categóricas deben ser etiquetadas como variables numéricas, no como cadenas.

# %%
from sklearn import preprocessing

# %%
cdata.head(5)
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender        age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-  49.307715      facebook            0       en
# 820tgsjxq7       MALE  38.000000      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.000000         basic            3       en
# bjjt8pjhuk     FEMALE  42.000000      facebook            0       en
# 87mebub9p4  -unknown-  41.000000         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %% [markdown]
# Debido a la cantidad de columnas con que cuenta nuestro Dataset se cambiarán solo algunas columnas categóricas a modo de ejemplo, puede observarse al final como estas columnas han pasado a ser numéricas:

# %%
column1='gender'
le1 = preprocessing.LabelEncoder()
le1.fit(cdata[column1])
print(dict(zip(le1.classes_,le1.transform(le1.classes_))))
cdata[column1] = le1.transform(cdata[column1]) 
cdata.head()
# Out:
# {'-unknown-': 0, 'FEMALE': 1, 'MALE': 2, 'OTHER': 3}
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#             gender        age signup_method  signup_flow language  \
# id
# gxn3p5htnn       0  49.307715      facebook            0       en
# 820tgsjxq7       2  38.000000      facebook            0       en
# 4ft3gnwmtx       1  56.000000         basic            3       en
# bjjt8pjhuk       1  42.000000      facebook            0       en
# 87mebub9p4       0  41.000000         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %% [markdown]
# En caso de un análisis para un caso real que se necesitan limpiar los datos este último proceso deberá realizarse para todas las columnas categóricas. Ahora guardaremos el último dateset procesado que hemos obtenido ya que revertiremos el cambio de las variables categóricas para continuar el análisis (en caso de una aplicación real no deberíamos invertirlo ya que necesitamos a las columnas categóricas como números):

# %%
cdata.to_csv("../Datos/Data_cat2num.csv")

# %%
cdata[column1] = le1.inverse_transform(cdata[column1])
cdata.head()
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender        age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-  49.307715      facebook            0       en
# 820tgsjxq7       MALE  38.000000      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.000000         basic            3       en
# bjjt8pjhuk     FEMALE  42.000000      facebook            0       en
# 87mebub9p4  -unknown-  41.000000         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  
# l56119iwg5     FEMALE  2014.0         basic            0       en
# w3fb6io74e  -unknown-  2014.0         basic            2       en
# ybblb7wzh8     FEMALE  2014.0         basic            2       en
# bbt3xydhoj     FEMALE  2014.0      facebook            2       en
# k1j9tg9tz2       MALE  2014.0      facebook            2       en
# fv4mcbvonv       MALE  2014.0         basic            2       en
# 8smg1h6o7t     FEMALE  2014.0         basic            6       en
# n2wz02fa45     FEMALE  2014.0         basic            3       en
# t92xz5zq9f     FEMALE  2013.0         basic            2       en
# i4ko79m5l9       MALE  2014.0      facebook            2       en
# bcfxgkh3ih     FEMALE  2014.0         basic            2       en
# k0bsp4ee32     FEMALE  2014.0         basic            2       en
# ...               ...     ...           ...          ...      ...
# bydzt91acn     FEMALE  2014.0         basic           25       en
# gme5odaoy8       MALE  2014.0         basic            0       en
# k33mpzbchn     FEMALE  2014.0         basic            0       en
# wr20jy7x3b     FEMALE  2014.0         basic            0       en
# 2ixvfk5v5w     FEMALE  2014.0         basic            0       en
# f7035f79ea       MALE  2014.0         basic            0       en
# d1v4vv3xj3  -unknown-  2014.0         basic            0       en
# ctacxe4tmz       MALE  2014.0         basic            0       en
# i3lxdnv96j  -unknown-  1928.0         basic           23       en
# sraouk5dve     FEMALE  1924.0         basic            0       en
# 6y8021owam     FEMALE  2014.0         basic            0       en
# bvt6c1d6uy       MALE  2014.0         basic            0       en
# hg0kddg0sp       MALE  2014.0         basic            0       en
# it9bzkxnhn     FEMALE  1936.0         basic           25       en
# veqakklrd0     FEMALE  2014.0         basic           24       en
# 96qhdng772     FEMALE  2014.0         basic            0       en
# 65tk02k88o     FEMALE  2014.0         basic            0       en
# 05d3awab7r       MALE  1929.0         basic           23       en
# 1nxkmkw8s7       MALE  1949.0         basic           23       en
# dgg8f0n573  -unknown-  2014.0         basic            0       en
# iy8r8edw4w       MALE  1931.0         basic           24       en
# si7du7o3yi       MALE  2014.0         basic            0       en
# yodsbl4xdz     FEMALE  2014.0         basic            0       en
# rbtiq1g2xk       MALE  1929.0         basic           24       en
# 8q4axsksl5       MALE  1947.0         basic           23       en
# 99y83scsje     FEMALE  1938.0         basic            0       en
# io7z9esqaj       MALE  1924.0      facebook           23       en
# zmlbfc7cso     FEMALE  1947.0         basic            0       en
# 0dn4tfj6gw     FEMALE  1949.0         basic            0       en
# 025sv1949e     FEMALE  1926.0         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# v2x0ms9c62             other         craigslist               untracked
# umf1wdk9uc             other         craigslist               untracked
# m82epwn7i8             other         craigslist               untracked
# 2th813zdx7            direct             direct               untracked
# 3amf04n3o3            direct             direct               untracked
# 6vpmryt377            direct             direct               untracked
# uxy91xb5p2            direct             direct               untracked
# bno0vva4uz             other         craigslist                  linked
# h3rrmak4tu             other         craigslist               untracked
# fou0j7fhnm     sem-non-brand             google               untracked
# kfeh5350pi            direct             direct               untracked
# 9aouhu15rk               seo             google                  linked
# aq0lqrjf2y     sem-non-brand             google                  linked
# 1w7fdi5pxc         sem-brand             google               untracked
# 8yv90v3y1f     sem-non-brand              other               untracked
# 0pyobdy4pq     sem-non-brand             google               untracked
# ezqp4a8cmw     sem-non-brand             google               untracked
# dguhdfl2l2            direct             direct                     omg
# l56119iwg5     sem-non-brand             google               untracked
# w3fb6io74e             other         craigslist               untracked
# ybblb7wzh8               seo             google                  linked
# bbt3xydhoj               seo             google                  linked
# k1j9tg9tz2               seo             google               untracked
# fv4mcbvonv     sem-non-brand             google               untracked
# 8smg1h6o7t            direct              other               untracked
# n2wz02fa45           content             google               untracked
# t92xz5zq9f             other         craigslist               untracked
# i4ko79m5l9            direct             direct               untracked
# bcfxgkh3ih            direct             direct                  linked
# k0bsp4ee32            direct             direct               untracked
# ...                      ...                ...                     ...
# bydzt91acn            direct             direct               untracked
# gme5odaoy8            direct             direct               untracked
# k33mpzbchn            direct             direct               untracked
# wr20jy7x3b               seo             google                 product
# 2ixvfk5v5w         sem-brand             google                     omg
# f7035f79ea         sem-brand             google                  linked
# d1v4vv3xj3     sem-non-brand             google                  linked
# ctacxe4tmz            direct             direct               untracked
# i3lxdnv96j            direct             direct               untracked
# sraouk5dve            direct             direct                  linked
# 6y8021owam       remarketing             google           tracked-other
# bvt6c1d6uy            direct             direct               untracked
# hg0kddg0sp            direct             direct               untracked
# it9bzkxnhn            direct             direct               untracked
# veqakklrd0            direct             direct                  linked
# 96qhdng772            direct             direct               untracked
# 65tk02k88o               seo             google                  linked
# 05d3awab7r            direct             direct               untracked
# 1nxkmkw8s7            direct             direct               untracked
# dgg8f0n573            direct             direct                     omg
# iy8r8edw4w            direct             direct               untracked
# si7du7o3yi               seo             google           tracked-other
# yodsbl4xdz            direct             direct                 product
# rbtiq1g2xk            direct             direct                  linked
# 8q4axsksl5            direct             direct               untracked
# 99y83scsje         sem-brand             google                     omg
# io7z9esqaj            direct             direct               untracked
# zmlbfc7cso               seo             google                  linked
# 0dn4tfj6gw            direct             direct               untracked
# 025sv1949e            direct             direct               untracked
#
#            signup_app   first_device_type       first_browser  \
# id
# v2x0ms9c62        Web     Windows Desktop             Firefox
# umf1wdk9uc        Web         Mac Desktop              Safari
# m82epwn7i8        Web         Mac Desktop              Chrome
# 2th813zdx7        Web         Mac Desktop              Chrome
# 3amf04n3o3        Web     Windows Desktop                  IE
# 6vpmryt377        Web         Mac Desktop             Firefox
# uxy91xb5p2        Web     Windows Desktop              Chrome
# bno0vva4uz        Web     Windows Desktop              Chrome
# h3rrmak4tu        Web         Mac Desktop              Safari
# fou0j7fhnm        Web     Windows Desktop              Chrome
# kfeh5350pi        Web         Mac Desktop             Firefox
# 9aouhu15rk        Web     Windows Desktop                  IE
# aq0lqrjf2y        Web                iPad       Mobile Safari
# 1w7fdi5pxc        Web         Mac Desktop              Safari
# 8yv90v3y1f        Web     Windows Desktop              Chrome
# 0pyobdy4pq        Web     Windows Desktop        AOL Explorer
# ezqp4a8cmw        Web     Windows Desktop             Firefox
# dguhdfl2l2        Web         Mac Desktop              Safari
# l56119iwg5        Web         Mac Desktop             Firefox
# w3fb6io74e        Web         Mac Desktop              Chrome
# ybblb7wzh8        Web         Mac Desktop              Safari
# bbt3xydhoj        Web         Mac Desktop             Firefox
# k1j9tg9tz2        Web         Mac Desktop              Chrome
# fv4mcbvonv        Web     Windows Desktop                  IE
# 8smg1h6o7t        Web              iPhone           -unknown-
# n2wz02fa45        Web     Windows Desktop                  IE
# t92xz5zq9f        Web       Android Phone           -unknown-
# i4ko79m5l9        Web         Mac Desktop              Chrome
# bcfxgkh3ih        Web         Mac Desktop              Safari
# k0bsp4ee32        Web         Mac Desktop             Firefox
# ...               ...                 ...                 ...
# bydzt91acn        iOS              iPhone           -unknown-
# gme5odaoy8        Web         Mac Desktop              Chrome
# k33mpzbchn        Web                iPad       Mobile Safari
# wr20jy7x3b        Web  SmartPhone (Other)  BlackBerry Browser
# 2ixvfk5v5w        Web         Mac Desktop              Safari
# f7035f79ea        Web                iPad       Mobile Safari
# d1v4vv3xj3        Web         Mac Desktop              Safari
# ctacxe4tmz        Web         Mac Desktop              Chrome
# i3lxdnv96j    Android       Other/Unknown           -unknown-
# sraouk5dve        Web     Windows Desktop              Chrome
# 6y8021owam        Web         Mac Desktop              Safari
# bvt6c1d6uy        Web     Windows Desktop             Firefox
# hg0kddg0sp        Web                iPad       Mobile Safari
# it9bzkxnhn        iOS              iPhone           -unknown-
# veqakklrd0      Moweb              iPhone       Chrome Mobile
# 96qhdng772        Web     Windows Desktop              Chrome
# 65tk02k88o        Web         Mac Desktop              Chrome
# 05d3awab7r    Android       Other/Unknown           -unknown-
# 1nxkmkw8s7    Android      Android Tablet           -unknown-
# dgg8f0n573        Web         Mac Desktop              Safari
# iy8r8edw4w      Moweb       Android Phone       Chrome Mobile
# si7du7o3yi        Web     Windows Desktop              Chrome
# yodsbl4xdz        Web     Windows Desktop              Chrome
# rbtiq1g2xk      Moweb       Android Phone       Chrome Mobile
# 8q4axsksl5    Android      Android Tablet           -unknown-
# 99y83scsje        Web     Windows Desktop                  IE
# io7z9esqaj    Android       Other/Unknown           -unknown-
# zmlbfc7cso        Web     Windows Desktop              Chrome
# 0dn4tfj6gw      Moweb       Android Phone       Chrome Mobile
# 025sv1949e        Web     Windows Desktop             Firefox
#
#            country_destination
# id
# v2x0ms9c62                  FR
# umf1wdk9uc                 NDF
# m82epwn7i8                  US
# 2th813zdx7                  US
# 3amf04n3o3                  US
# 6vpmryt377                  CA
# uxy91xb5p2                  US
# bno0vva4uz                 NDF
# h3rrmak4tu                 NDF
# fou0j7fhnm                  US
# kfeh5350pi               other
# 9aouhu15rk                  US
# aq0lqrjf2y                  FR
# 1w7fdi5pxc                 NDF
# 8yv90v3y1f                  US
# 0pyobdy4pq                  US
# ezqp4a8cmw                 NDF
# dguhdfl2l2                  US
# l56119iwg5                  US
# w3fb6io74e                 NDF
# ybblb7wzh8                 NDF
# bbt3xydhoj                  US
# k1j9tg9tz2                  US
# fv4mcbvonv                 NDF
# 8smg1h6o7t               other
# n2wz02fa45                  US
# t92xz5zq9f                  US
# i4ko79m5l9                  DE
# bcfxgkh3ih                 NDF
# k0bsp4ee32               other
# ...                        ...
# bydzt91acn                 NDF
# gme5odaoy8                 NDF
# k33mpzbchn                  US
# wr20jy7x3b                 NDF
# 2ixvfk5v5w                 NDF
# f7035f79ea                 NDF
# d1v4vv3xj3                  US
# ctacxe4tmz                  US
# i3lxdnv96j                 NDF
# sraouk5dve                  US
# 6y8021owam                  US
# bvt6c1d6uy                 NDF
# hg0kddg0sp                  GB
# it9bzkxnhn                 NDF
# veqakklrd0                 NDF
# 96qhdng772                  US
# 65tk02k88o                  US
# 05d3awab7r                  US
# 1nxkmkw8s7                  US
# dgg8f0n573                  US
# iy8r8edw4w                  US
# si7du7o3yi                 NDF
# yodsbl4xdz                  US
# rbtiq1g2xk                  US
# 8q4axsksl5               other
# 99y83scsje                  US
# io7z9esqaj                  US
# zmlbfc7cso                  US
# 0dn4tfj6gw                 NDF
# 025sv1949e                  US
#
# [745 rows x 15 columns]

# %% [markdown]
# * __TO DO__: Buscar inconsistencias y corregirlas, explicando el criterio de corrección seleccionado.

# %%
cdata.age.describe()
# Out:
# count    207386.000000
# mean         49.307715
# std         118.421878
# min           1.000000
# 25%          32.000000
# 50%          49.000000
# 75%          49.307715
# max        2014.000000
# Name: age, dtype: float64

# %% [markdown]
# Se observan valores exentricos como 2014 o 1, vamos a basarnos en un rango entre 18 y 100 para la edad y transformamos el resto en NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cdata.loc[cdata['age'] < 18, 'age'] = np.NaN
cdata.loc[cdata['age'] > 100, 'age']= np.NaN

#volvemos a reemplazar los valores nulos por la media de age
cdata['age'].fillna(cdata['age'].mean(), inplace=True)


plt.figure(figsize=(10,6))
sns.distplot(cdata['age'].dropna())

# %% [markdown]
# ## 10. Identificar y documentar valores atípicos/outliers

# %% [markdown]
# Debido a la gran cantidad de columnas que posee nuestro Dataset, procederemos a realizar el análisis sobre una categoría a modo de ejemplo. Dichas categorías serán __age__:

# %%
cdata.head(5)
# Out:
#            date_account_created timestamp_first_active date_first_booking  \
# id
# gxn3p5htnn           2010-06-28    2009-03-19 04:32:55                NaT
# 820tgsjxq7           2011-05-25    2009-05-23 17:48:09                NaT
# 4ft3gnwmtx           2010-09-28    2009-06-09 23:12:47         2010-08-02
# bjjt8pjhuk           2011-12-05    2009-10-31 06:01:29         2012-09-08
# 87mebub9p4           2010-09-14    2009-12-08 06:11:05         2010-02-18
#
#                gender        age signup_method  signup_flow language  \
# id
# gxn3p5htnn  -unknown-  49.307715      facebook            0       en
# 820tgsjxq7       MALE  38.000000      facebook            0       en
# 4ft3gnwmtx     FEMALE  56.000000         basic            3       en
# bjjt8pjhuk     FEMALE  42.000000      facebook            0       en
# 87mebub9p4  -unknown-  41.000000         basic            0       en
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# gxn3p5htnn            direct             direct               untracked
# 820tgsjxq7               seo             google               untracked
# 4ft3gnwmtx            direct             direct               untracked
# bjjt8pjhuk            direct             direct               untracked
# 87mebub9p4            direct             direct               untracked
#
#            signup_app first_device_type first_browser country_destination
# id
# gxn3p5htnn        Web       Mac Desktop        Chrome                 NDF
# 820tgsjxq7        Web       Mac Desktop        Chrome                 NDF
# 4ft3gnwmtx        Web   Windows Desktop            IE                  US
# bjjt8pjhuk        Web       Mac Desktop       Firefox               other
# 87mebub9p4        Web       Mac Desktop        Chrome                  US

# %% [markdown]
# Comenzamos el análisis con un histograma donde podemos observar donde se encuentran la mayor parte de los valores.

# %%
# %matplotlib inline
cdata.age.hist(figsize=(10,10));

# %% [markdown]
# Pero en este caso, para el análisis de outliers un gráfico de caja nos proveerá mucha más información:

# %%
plt.figure(figsize=(7,8))
sns.boxplot(y='age', data=cdata)

# %% [markdown]
# 59xut9710t     FEMALE   95.0      facebook            0       en
# ...               ...    ...           ...          ...      ...
# v2wet7ba0l     FEMALE   84.0      facebook            0       en
# w1248jtky0     FEMALE  100.0      facebook            0       en
# rhhxx6l0db       MALE   99.0      facebook            0       en
# jcdblgyko1       MALE   96.0      facebook            0       en
# zdruzsogmj     FEMALE   85.0      facebook            0       en
# 6ulbti0fux     FEMALE   75.0         basic            0       en
# huwlsxz87q       MALE   80.0         basic            0       en
# svxhjcsk61     FEMALE   89.0      facebook            0       en
# lqueitur7g     FEMALE   76.0         basic            0       en
# 9giz09bsmz       MALE   82.0      facebook            0       en
# bdekgjdtsc  -unknown-   84.0         basic            0       en
# ju4v42l2r3       MALE   81.0      facebook            0       it
# 31cb8lr3vg       MALE   93.0         basic            0       en
# s5esy69dds       MALE   95.0      facebook            0       en
# qst901xoyq     FEMALE   93.0      facebook            0       en
# xn676v2yb7       MALE   96.0      facebook           25       en
# 5okewk4psr  -unknown-   83.0         basic            0       en
# prw5rjztfn     FEMALE   80.0         basic            0       en
# torjtc5bt8     FEMALE   80.0      facebook            0       en
# x1kd3fm9f5     FEMALE   91.0      facebook           25       es
# 4d3514kmcp  -unknown-   75.0         basic            0       en
# htevetadbu     FEMALE   75.0      facebook            0       en
# dahlmgshv4       MALE   78.0         basic            0       en
# u2hbajs6m7       MALE   79.0         basic            0       en
# u13vudpnue  -unknown-   88.0      facebook            0       en
# j7xbbox53t       MALE   82.0         basic            0       en
# p6efkjvhld     FEMALE   89.0         basic            0       en
# kl0rhr0o7i     FEMALE   75.0         basic            0       en
# ab3s6b58w5     FEMALE   81.0         basic            0       en
# pw9nfo1ulb     FEMALE   95.0      facebook            0       fr
#
#            affiliate_channel affiliate_provider first_affiliate_tracked  \
# id
# ixv5186g1h            direct             direct               untracked
# kqf8b3ta98           content             google                  linked
# i4v7ucn9aa     sem-non-brand              other               untracked
# 77qfjwd8uv           content           facebook               untracked
# 9lkved7fhg               seo             google               untracked
# 8wxkkbpwuk            direct             direct               untracked
# g4pymtxkrk     sem-non-brand             google               untracked
# cmaysyaya1            direct             direct               untracked
# lp1ddk7ps2         sem-brand             google               untracked
# wohy9u0us5     sem-non-brand             google               untracked
# r1ysk5luce     sem-non-brand             google                     omg
# l8qqhvbq3u             other         craigslist                  linked
# 9c60tc72zo     sem-non-brand             google                     omg
# enyp8tn6sj            direct             direct                  linked
# yrfmcrps9h            direct             direct                  linked
# 8xaapjekt4            direct             direct                  linked
# sq67a3i0v4     sem-non-brand               bing                     omg
# 4qwmy5moro               seo             google               untracked
# li5yod6tjg       remarketing             google                     omg
# cf0v6g93yj     sem-non-brand             google                     omg
# in2cduaucf            direct             direct                  linked
# vrlns8g94u     sem-non-brand             google                  linked
# 01c3im19hx       remarketing             google                  linked
# d41glc31df            direct             direct               untracked
# 982wwg9eli            direct             direct               untracked
# ov87ccn84u            direct             direct           tracked-other
# tkthlgavii            direct             direct               untracked
# 6f4o4rxmk4     sem-non-brand             google               untracked
# ij4mdrov3u         sem-brand             google                  linked
# 59xut9710t     sem-non-brand             google               untracked
# ...                      ...                ...                     ...
# v2wet7ba0l            direct             direct               untracked
# w1248jtky0               seo             google                  linked
# rhhxx6l0db     sem-non-brand             google                     omg
# jcdblgyko1            direct             direct               untracked
# zdruzsogmj            direct             direct                  linked
# 6ulbti0fux         sem-brand             google                     omg
# huwlsxz87q         sem-brand             google                     omg
# svxhjcsk61            direct             direct                  linked
# lqueitur7g         sem-brand             google                     omg
# 9giz09bsmz            direct             direct                 product
# bdekgjdtsc         sem-brand             google                     omg
# ju4v42l2r3            direct             direct                  linked
# 31cb8lr3vg         sem-brand             google               untracked
# s5esy69dds            direct             direct                  linked
# qst901xoyq         sem-brand             google                     omg
# xn676v2yb7            direct             direct               untracked
# 5okewk4psr         sem-brand             google                     omg
# prw5rjztfn         sem-brand             google                     omg
# torjtc5bt8         sem-brand             google                     omg
# x1kd3fm9f5            direct             direct               untracked
# 4d3514kmcp               seo               bing                  linked
# htevetadbu         sem-brand             google                     omg
# dahlmgshv4         sem-brand             google                     omg
# u2hbajs6m7     sem-non-brand             google                     omg
# u13vudpnue            direct             direct                  linked
# j7xbbox53t            direct             direct               untracked
# p6efkjvhld         sem-brand             google                     omg
# kl0rhr0o7i         sem-brand             google               untracked
# ab3s6b58w5         sem-brand             google               untracked
# pw9nfo1ulb               seo           facebook                  linked
#
#            signup_app first_device_type  first_browser country_destination
# id
# ixv5186g1h        Web       Mac Desktop        Firefox                 NDF
# kqf8b3ta98        Web       Mac Desktop         Safari                 NDF
# i4v7ucn9aa        Web       Mac Desktop         Safari                  US
# 77qfjwd8uv        Web   Windows Desktop         Chrome                  US
# 9lkved7fhg        Web       Mac Desktop         Safari                  US
# 8wxkkbpwuk        Web   Windows Desktop        Firefox                  US
# g4pymtxkrk        Web              iPad  Mobile Safari                  US
# cmaysyaya1        Web       Mac Desktop         Chrome               other
# lp1ddk7ps2        Web   Windows Desktop             IE                 NDF
# wohy9u0us5        Web              iPad  Mobile Safari                 NDF
# r1ysk5luce        Web       Mac Desktop        Firefox                 NDF
# l8qqhvbq3u        Web       Mac Desktop         Safari                 NDF
# 9c60tc72zo        Web              iPad  Mobile Safari                 NDF
# enyp8tn6sj        Web   Windows Desktop        Firefox                  NL
# yrfmcrps9h        Web   Windows Desktop             IE                  US
# 8xaapjekt4        Web       Mac Desktop         Safari                 NDF
# sq67a3i0v4        Web    Android Tablet             IE                 NDF
# 4qwmy5moro        Web              iPad  Mobile Safari                  IT
# li5yod6tjg        Web   Windows Desktop        Firefox                 NDF
# cf0v6g93yj        Web   Windows Desktop             IE                 NDF
# in2cduaucf        Web            iPhone  Mobile Safari                 NDF
# vrlns8g94u        Web   Windows Desktop             IE                 NDF
# 01c3im19hx        Web       Mac Desktop         Safari                  US
# d41glc31df        Web       Mac Desktop         Chrome                  ES
# 982wwg9eli        Web       Mac Desktop         Chrome               other
# ov87ccn84u        Web              iPad  Mobile Safari                 NDF
# tkthlgavii        Web            iPhone      -unknown-                 NDF
# 6f4o4rxmk4        Web       Mac Desktop        Firefox                  ES
# ij4mdrov3u        Web   Windows Desktop             IE                 NDF
# 59xut9710t        Web       Mac Desktop         Safari                  US
# ...               ...               ...            ...                 ...
# v2wet7ba0l        Web       Mac Desktop         Safari                 NDF
# w1248jtky0        Web              iPad  Mobile Safari                 NDF
# rhhxx6l0db        Web       Mac Desktop         Chrome                 NDF
# jcdblgyko1        Web   Windows Desktop        Firefox               other
# zdruzsogmj        Web   Windows Desktop         Chrome                 NDF
# 6ulbti0fux        Web              iPad  Mobile Safari                  US
# huwlsxz87q        Web       Mac Desktop         Safari                  US
# svxhjcsk61        Web              iPad  Mobile Safari                 NDF
# lqueitur7g        Web   Windows Desktop         Chrome                 NDF
# 9giz09bsmz        Web   Windows Desktop        Firefox                 NDF
# bdekgjdtsc        Web       Mac Desktop         Chrome                 NDF
# ju4v42l2r3        Web       Mac Desktop         Safari                 NDF
# 31cb8lr3vg        Web       Mac Desktop        Firefox                  US
# s5esy69dds        Web       Mac Desktop         Safari                  US
# qst901xoyq        Web       Mac Desktop         Safari                 NDF
# xn676v2yb7        iOS            iPhone      -unknown-                 NDF
# 5okewk4psr        Web   Windows Desktop             IE                 NDF
# prw5rjztfn        Web       Mac Desktop        Firefox               other
# torjtc5bt8        Web   Windows Desktop        Firefox                 NDF
# x1kd3fm9f5        iOS            iPhone      -unknown-                 NDF
# 4d3514kmcp        Web    Android Tablet             IE                  US
# htevetadbu        Web       Mac Desktop         Safari                 NDF
# dahlmgshv4        Web       Mac Desktop         Chrome                 NDF
# u2hbajs6m7        Web   Windows Desktop             IE                  GB
# u13vudpnue      Moweb     Android Phone  Chrome Mobile                 NDF
# j7xbbox53t        Web   Windows Desktop             IE                 NDF
# p6efkjvhld        Web   Windows Desktop        Firefox                  US
# kl0rhr0o7i        Web       Mac Desktop        Firefox                  US
# ab3s6b58w5        Web              iPad  Mobile Safari                 NDF
# pw9nfo1ulb      Moweb            iPhone  Mobile Safari                 NDF
#
# [783 rows x 15 columns]

# %% [markdown]
# * __TO DO__: ¿Qué deberíamos hacer con estos outliers? ¿Son factibles a una corrección? ¿Los debemos eliminar?

# %% [markdown]
# En este caso, teniendo en cuenta ya hemos limpiado los valores descomunales y saneado los NaN y observando que estos outliers han tenido actividad de first_booking no los eliminaremos.

# %% [markdown]
# Si quisieramos hacer un análisis más profundo podríamos realizar gŕaficos de caja de las columnas de interés con respecto a otras. En este caso graficamos __age__ dependiendo del __gender__.

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='gender', y='age', data=cdata)

# %% [markdown]
# * __TO DO__: Repetir el análisis con las demás columnas para poder completar la curación de los datos.

# %% [markdown]
# ## 11. Evaluar cómo comprimir los datos

# %% [markdown]
# En la actualidad, en las nubes el almacenamiento no suele ser problema sino la velocidad para leerlo que suele ser determinante a la hora de determinar el formato de almacenamiento. Esto es debido a que generalmente los datos se guardan una vez (o con una frecuencia muy baja) pero necesitaremos leerlos constantemente.

# %% [markdown]
# ## 12. Guardar el set de datos con un nombre informativo

# %% [markdown]
# El nombre del dataset original es __data.csv__

# %%
cdata.to_csv("../Datos/data_cleaned.csv")
